# %% [markdown]
# # **Polynomial Regression**

# %% [markdown]
# ### **Importing the Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### **Importing the dataset**

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values #leaving the first column
Y = dataset.iloc[:, -1].values

# %% [markdown]
# ### **Training the linear regression model on the whole dataset**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Training the polynomial regression model on the whole dataset**

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 6)
X_poly = poly_reg.fit_transform(X)
print(X_poly)
regressor2 = LinearRegression()
regressor2.fit(X_poly,Y)
# Out:
# [[1.00000e+00 1.00000e+00 1.00000e+00 1.00000e+00 1.00000e+00 1.00000e+00
#   1.00000e+00]
#  [1.00000e+00 2.00000e+00 4.00000e+00 8.00000e+00 1.60000e+01 3.20000e+01
#   6.40000e+01]
#  [1.00000e+00 3.00000e+00 9.00000e+00 2.70000e+01 8.10000e+01 2.43000e+02
#   7.29000e+02]
#  [1.00000e+00 4.00000e+00 1.60000e+01 6.40000e+01 2.56000e+02 1.02400e+03
#   4.09600e+03]
#  [1.00000e+00 5.00000e+00 2.50000e+01 1.25000e+02 6.25000e+02 3.12500e+03
#   1.56250e+04]
#  [1.00000e+00 6.00000e+00 3.60000e+01 2.16000e+02 1.29600e+03 7.77600e+03
#   4.66560e+04]
#  [1.00000e+00 7.00000e+00 4.90000e+01 3.43000e+02 2.40100e+03 1.68070e+04
#   1.17649e+05]
#  [1.00000e+00 8.00000e+00 6.40000e+01 5.12000e+02 4.09600e+03 3.27680e+04
#   2.62144e+05]
#  [1.00000e+00 9.00000e+00 8.10000e+01 7.29000e+02 6.56100e+03 5.90490e+04
#   5.31441e+05]
#  [1.00000e+00 1.00000e+01 1.00000e+02 1.00000e+03 1.00000e+04 1.00000e+05
#   1.00000e+06]]
# LinearRegression()

# %% [markdown]
# ### **Visualizing the Linear Regression Results**

# %%
plt.scatter(X,Y, color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.title('Truth or Bluff(Linear regression Model)')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### **Visualizing the Polynomial Regression Results**

# %%
plt.scatter(X,Y, color = 'red')
plt.plot(X, regressor2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff(Polynomial regression Model)')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### **Predicting a new result with Linear Regression**

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# 6.5 is denotion to the person who's joining as a region manager i.e., level 6 and so salary expectations can be measured in b/w of 6 and 7

# %% [markdown]
# ### **Predicting a new result with Polynomial Regression**

# %%
regressor2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([174192.81930595])

# %% [markdown]
# ### **Salary one could offer to the new joiner (as a region manager) would be 174,192$ ~**
